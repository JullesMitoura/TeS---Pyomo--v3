# %%
from app.aux.entropyZero import int_cp_T
from app.aux.read_data import ReadData
import pyomo.environ as pyo
import numpy as np
import pandas as pd

# %%
data_path = 'Informations.csv'
data, species, initial, components = ReadData(data_path).get_infos()
total_species = len(species)

# %%
def identify_phases(phase_type, data):
    """
    Identifies the components that belong to the given phase type ('s' for solids, 'g' for gases).
    """
    return [i for i, comp in enumerate(data) if data[comp].get("Phase") == phase_type]

# %%
gas_comps = identify_phases('g',data)
solid_comps = identify_phases('s',data)

# %%
A = np.array([[component[specie] for specie in species] for component in data.values()])

def bnds_values(initial, data, inhibited_component=None):
    """
    Returns the bounds for the variables based on the initial guess and the inhibited component.
    """
    max_species = np.dot(initial, A)
    epsilon = 1e-05
    bnds_aux = []

    if inhibited_component and inhibited_component != '---':
        try:
            aux_idx = next(index for index, value in data.items() if value['Component'] == inhibited_component)
        except StopIteration:
            print(f"Inhibited component '{inhibited_component}' not found.")
            aux_idx = None
    else:
        aux_idx = None

    for i, comp in enumerate(data):
        if aux_idx is not None and i == aux_idx:
            bnds_aux.append((1e-8, epsilon))
        else:
            a = np.multiply(1 / np.where(A[i] != 0, A[i], np.inf), max_species)
            upper_bound = np.min(a[a > 0]) if a[a > 0].size > 0 else epsilon
            bnds_aux.append((1e-8, max(upper_bound, epsilon)))

    return tuple(bnds_aux)

# %%
total_components = len(components)

def solve_entropy(initial, Tinit, P):
    initial[initial == 0] = 0.00001
    bnds = bnds_values(initial, data)
    model = pyo.ConcreteModel()
    model.n = pyo.Var(range(total_components), domain=pyo.NonNegativeReals, bounds=lambda m, i: bnds[i])
    model.T = pyo.Var(domain=pyo.NonNegativeReals, bounds=(500, 1600), initialize=Tinit)

    gases = identify_phases('g', data)

    def entropy_rule(model):
        T0 = 298.15
        R = 8.314  # J/mol·K

        int_cp_T_values, deltaH, deltaG = int_cp_T(model.T, data)

        mi_gas = [
            ((deltaH[i] - deltaG[i]) / T0) - R * pyo.log(P) - R * pyo.log(model.n[i] / sum(model.n) + int_cp_T_values[i])
            for i in gases
        ]

        regularization_term = 1e-6
        total_gibbs = sum(mi_gas[i] * model.n[gases[i]] for i in range(len(mi_gas))) + regularization_term
        
        return total_gibbs

    model.obj = pyo.Objective(rule=entropy_rule, sense=pyo.maximize)
    model.element_balance = pyo.ConstraintList()
    for i in range(total_species):
        tolerance = 1e-8
        lhs = sum(A[j, i] * model.n[j] for j in range(total_components))
        rhs = sum(A[j, i] * initial[j] for j in range(total_components))
        model.element_balance.add(pyo.inequality(-tolerance, lhs - rhs, tolerance))

    solver = pyo.SolverFactory('ipopt')
    solver.options['tol'] = 1e-1
    solver.options['max_iter'] = 5000
    solver.options['acceptable_tol'] = 1e-6
    solver.options['acceptable_obj_change_tol'] = 1e-6
    results = solver.solve(model, tee=False)

    if results.solver.termination_condition == pyo.TerminationCondition.optimal:
        optimized_n = [pyo.value(model.n[i]) for i in range(total_components)]
        Teq = pyo.value(model.T)
        return optimized_n, Teq
    else:
        raise Exception("Optimal solution not found.")

# %%
res = solve_entropy(initial,1000,220)
res
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 res = solve_entropy(initial,1000,220)
#       2 res
#
# Cell In[6], line 41, in solve_entropy(initial, Tinit, P)
#      39 solver.options['acceptable_tol'] = 1e-6
#      40 solver.options['acceptable_obj_change_tol'] = 1e-6
# ---> 41 results = solver.solve(model, tee=False)
#      43 if results.solver.termination_condition == pyo.TerminationCondition.optimal:
#      44     optimized_n = [pyo.value(model.n[i]) for i in range(total_components)]
#
# File ~/Desktop/GitHub/TeS---Pyomo/.venv/lib/python3.11/site-packages/pyomo/opt/base/solvers.py:662, in OptSolver.solve(self, *args, **kwds)
#     660 else:
#     661     if self._load_solutions:
# --> 662         _model.solutions.load_from(
#     663             result,
#     664             select=self._select_index,
#     665             default_variable_value=self._default_variable_value,
#     666         )
#     667         result._smap_id = None
#     668         result.solution.clear()
#
# File ~/Desktop/GitHub/TeS---Pyomo/.venv/lib/python3.11/site-packages/pyomo/core/base/PyomoModel.py:228, in ModelSolutions.load_from(self, results, allow_consistent_values_for_fixed_vars, comparison_tolerance_for_fixed_vars, ignore_invalid_labels, id, delete_symbol_map, clear, default_variable_value, select, ignore_fixed_vars)
#     223         logger.warning(
#     224             "Loading a SolverResults object with "
#     225             "an 'aborted' status, but containing a solution"
#     226         )
#     227     else:
# --> 228         raise ValueError(
#     229             "Cannot load a SolverResults object "
#     230             "with bad status: %s" % str(results.solver.status)
#     231         )
#     232 if clear:
#     233     #
#     234     # Clear the solutions, but not the symbol map
#     235     #
#     236     self.clear(clear_symbol_maps=False)
#
# ValueError: Cannot load a SolverResults object with bad status: error

# %%
data
# Out:
# {0: {'Component': 'Methane',
#   'Phase': 'g',
#   'a': 1.702,
#   'b': 0.009081,
#   'c': -2.164e-06,
#   'd': 0.0,
#   '∆Hf298': -74520.0,
#   '∆Gf298': -50460.0,
#   'Pc': 45.99,
#   'Tc': 190.6,
#   'omega': 0.012,
#   'Tmax': 1500,
#   'initial': 0.0,
#   'C': 1,
#   'H': 4.0,
#   'O': 0.0,
#   'N': 0.0},
#  1: {'Component': 'Water',
#   'Phase': 'g',
#   'a': 3.47,
#   'b': 0.00145,
#   'c': 0.0,
#   'd': 12100.0,
#   '∆Hf298': -241818.0,
#   '∆Gf298': -228572.0,
#   'Pc': 220.55,
#   'Tc': 647.1,
#   'omega': 0.345,
#   'Tmax': 1500,
#   'initial': 2.0,
#   'C': 0,
#   'H': 2.0,
#   'O': 1.0,
#   'N': 0.0},
#  2: {'Component': 'CarbonMonoxide',
#   'Phase': 'g',
#   'a': 3.376,
#   'b': 0.000557,
#   'c': 0.0,
#   'd': -3100.0,
#   '∆Hf298': -110525.0,
#   '∆Gf298': -137169.0,
#   'Pc': 34.99,
#   'Tc': 132.9,
#   'omega': 0.048,
#   'Tmax': 1500,
#   'initial': 0.0,
#   'C': 1,
#   'H': 0.0,
#   'O': 1.0,
#   'N': 0.0},
#  3: {'Component': 'CarbonDioxide',
#   'Phase': 'g',
#   'a': 5.457,
#   'b': 0.001045,
#   'c': 0.0,
#   'd': -115700.0,
#   '∆Hf298': -393509.0,
#   '∆Gf298': -394359.0,
#   'Pc': 73.83,
#   'Tc': 304.2,
#   'omega': 0.224,
#   'Tmax': 1500,
#   'initial': 0.0,
#   'C': 1,
#   'H': 0.0,
#   'O': 2.0,
#   'N': 0.0},
#  4: {'Component': 'Hydrogen',
#   'Phase': 'g',
#   'a': 3.249,
#   'b': 0.000422,
#   'c': 0.0,
#   'd': 8300.0,
#   '∆Hf298': 0.0,
#   '∆Gf298': 0.0,
#   'Pc': 13.13,
#   'Tc': 33.19,
#   'omega': -0.216,
#   'Tmax': 1500,
#   'initial': 0.0,
#   'C': 0,
#   'H': 2.0,
#   'O': 0.0,
#   'N': 0.0},
#  5: {'Component': 'Methanol',
#   'Phase': 'g',
#   'a': 2.211,
#   'b': 0.012216,
#   'c': -3.45e-06,
#   'd': 0.0,
#   '∆Hf298': -200660.0,
#   '∆Gf298': -161960.0,
#   'Pc': 80.97,
#   'Tc': 512.6,
#   'omega': 0.564,
#   'Tmax': 1500,
#   'initial': 0.0,
#   'C': 1,
#   'H': 4.0,
#   'O': 1.0,
#   'N': 0.0},
#  6: {'Component': 'Ethane',
#   'Phase': 'g',
#   'a': 1.131,
#   'b': 0.019225,
#   'c': -5.561e-06,
#   'd': 0.0,
#   '∆Hf298': -83820.0,
#   '∆Gf298': -31855.0,
#   'Pc': 48.72,
#   'Tc': 305.3,
#   'omega': 0.1,
#   'Tmax': 1500,
#   'initial': 0.0,
#   'C': 2,
#   'H': 6.0,
#   'O': 0.0,
#   'N': 0.0},
#  7: {'Component': 'Propane',
#   'Phase': 'g',
#   'a': 1.213,
#   'b': 0.028785,
#   'c': -8.824e-06,
#   'd': 0.0,
#   '∆Hf298': -104680.0,
#   '∆Gf298': -24290.0,
#   'Pc': 42.48,
#   'Tc': 369.8,
#   'omega': 0.152,
#   'Tmax': 1500,
#   'initial': 0.0,
#   'C': 3,
#   'H': 8.0,
#   'O': 0.0,
#   'N': 0.0},
#  8: {'Component': 'Butane',
#   'Phase': 'g',
#   'a': 1.935,
#   'b': 0.036915,
#   'c': -1.1402e-05,
#   'd': 0.0,
#   '∆Hf298': -125790.0,
#   '∆Gf298': -16570.0,
#   'Pc': 37.96,
#   'Tc': 425.1,
#   'omega': 0.2,
#   'Tmax': 1500,
#   'initial': 0.0,
#   'C': 4,
#   'H': 10.0,
#   'O': 0.0,
#   'N': 0.0},
#  9: {'Component': 'Nitrogen',
#   'Phase': 'g',
#   'a': 3.28,
#   'b': 0.000593,
#   'c': 0.0,
#   'd': 4000.0,
#   '∆Hf298': 0.0,
#   '∆Gf298': 0.0,
#   'Pc': 34.0,
#   'Tc': 126.2,
#   'omega': 0.038,
#   'Tmax': 1500,
#   'initial': 0.0,
#   'C': 0,
#   'H': 0.0,
#   'O': 0.0,
#   'N': 2.0},
#  10: {'Component': 'Ammonia',
#   'Phase': 'g',
#   'a': 3.578,
#   'b': 0.00302,
#   'c': 0.0,
#   'd': -18600.0,
#   '∆Hf298': -46110.0,
#   '∆Gf298': -16400.0,
#   'Pc': 112.8,
#   'Tc': 405.7,
#   'omega': 0.253,
#   'Tmax': 1500,
#   'initial': 0.0,
#   'C': 0,
#   'H': 3.0,
#   'O': 0.0,
#   'N': 1.0},
#  11: {'Component': 'EnergySugarCane',
#   'Phase': 'g',
#   'a': 0.0,
#   'b': 0.0,
#   'c': 0.0,
#   'd': 0.0,
#   '∆Hf298': -160000.0,
#   '∆Gf298': -114300.0,
#   'Pc': 75.0,
#   'Tc': 850.0,
#   'omega': 0.51269,
#   'Tmax': 1500,
#   'initial': 0.0,
#   'C': 1,
#   'H': 1.82,
#   'O': 0.657,
#   'N': 0.0063},
#  12: {'Component': 'CoffeeHusk',
#   'Phase': 'g',
#   'a': 0.0,
#   'b': 0.0,
#   'c': 0.0,
#   'd': 0.0,
#   '∆Hf298': -160000.0,
#   '∆Gf298': -114300.0,
#   'Pc': 75.0,
#   'Tc': 850.0,
#   'omega': 0.51269,
#   'Tmax': 1500,
#   'initial': 0.0,
#   'C': 1,
#   'H': 0.745,
#   'O': 0.369,
#   'N': 0.029},
#  13: {'Component': 'EucalyptusBio',
#   'Phase': 'g',
#   'a': 0.0,
#   'b': 0.0,
#   'c': 0.0,
#   'd': 0.0,
#   '∆Hf298': -160000.0,
#   '∆Gf298': -114300.0,
#   'Pc': 75.0,
#   'Tc': 850.0,
#   'omega': 0.51269,
#   'Tmax': 1500,
#   'initial': 0.0,
#   'C': 1,
#   'H': 0.496,
#   'O': 0.322,
#   'N': 0.011},
#  14: {'Component': 'WasteFuel',
#   'Phase': 'g',
#   'a': 0.0,
#   'b': 0.0,
#   'c': 0.0,
#   'd': 0.0,
#   '∆Hf298': -160000.0,
#   '∆Gf298': -114300.0,
#   'Pc': 75.0,
#   'Tc': 850.0,
#   'omega': 0.51269,
#   'Tmax': 1500,
#   'initial': 0.0,
#   'C': 1,
#   'H': 2.138,
#   'O': 0.46,
#   'N': 0.015},
#  15: {'Component': 'Microalgae',
#   'Phase': 'g',
#   'a': 0.0,
#   'b': 0.0,
#   'c': 0.0,
#   'd': 0.0,
#   '∆Hf298': -160000.0,
#   '∆Gf298': -114300.0,
#   'Pc': 75.0,
#   'Tc': 850.0,
#   'omega': 0.51269,
#   'Tmax': 1500,
#   'initial': 0.5,
#   'C': 1,
#   'H': 1.87,
#   'O': 0.59,
#   'N': 0.13},
#  16: {'Component': 'Carbon',
#   'Phase': 's',
#   'a': 1.771,
#   'b': 0.000771,
#   'c': 0.0,
#   'd': -86700.0,
#   '∆Hf298': 0.0,
#   '∆Gf298': 0.0,
#   'Pc': 0.0,
#   'Tc': 0.0,
#   'omega': 0.0,
#   'Tmax': 2000,
#   'initial': 0.0,
#   'C': 1,
#   'H': 0.0,
#   'O': 0.0,
#   'N': 0.0}}
